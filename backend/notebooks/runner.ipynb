# %%
import yaml
from graph.graph_builder import build_graph, draw_graph

# Load config
with open("config/config.yaml", "r") as f:
    config = yaml.safe_load(f)

# Build LangGraph app
app = build_graph(config)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import yaml
# ----> 2 from graph.graph_builder import build_graph, draw_graph
#       4 # Load config
#       5 with open("config/config.yaml", "r") as f:
#
# ModuleNotFoundError: No module named 'graph'
